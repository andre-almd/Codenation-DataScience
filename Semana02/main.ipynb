# %% [markdown]
# # Desafio 1
#
# Para esse desafio, vamos trabalhar com o data set [Black Friday](https://www.kaggle.com/mehdidag/black-friday), que reúne dados sobre transações de compras em uma loja de varejo.
#
# Vamos utilizá-lo para praticar a exploração de data sets utilizando pandas. Você pode fazer toda análise neste mesmo notebook, mas as resposta devem estar nos locais indicados.
#
# > Obs.: Por favor, não modifique o nome das funções de resposta.

# %% [markdown]
# ## _Set up_ da análise

# %%
import pandas as pd
import numpy as np

# %%
black_friday = pd.read_csv("black_friday.csv")

# %% [markdown]
# ## Inicie sua análise a partir daqui

# %%
black_friday.head(50)
# Out:
#     User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0   1000001  P00069042      F   0-17          10             A
# 1   1000001  P00248942      F   0-17          10             A
# 2   1000001  P00087842      F   0-17          10             A
# 3   1000001  P00085442      F   0-17          10             A
# 4   1000002  P00285442      M    55+          16             C
# 5   1000003  P00193542      M  26-35          15             A
# 6   1000004  P00184942      M  46-50           7             B
# 7   1000004  P00346142      M  46-50           7             B
# 8   1000004   P0097242      M  46-50           7             B
# 9   1000005  P00274942      M  26-35          20             A
# 10  1000005  P00251242      M  26-35          20             A
# 11  1000005  P00014542      M  26-35          20             A
# 12  1000005  P00031342      M  26-35          20             A
# 13  1000005  P00145042      M  26-35          20             A
# ...

# %%
#q1

black_friday.shape[0], black_friday.shape[1]
type((black_friday.shape[0], black_friday.shape[1]))
# Out:
# tuple

# %%
#q2

select = black_friday[(black_friday['Age'] == '26-35') & (black_friday['Gender'] == 'F')]
select.shape[0]
# Out:
# 49348

# %%
#q3

black_friday['User_ID'].nunique()

type(int(black_friday['User_ID'].nunique()))
# Out:
# int

# %%
#q4

black_friday.dtypes.nunique()

type(int(black_friday.dtypes.nunique()))
# Out:
# int

# %%
black_friday.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
#q5

print((black_friday.isnull().sum().max())/len(black_friday))
print(373299/len(black_friday))

print((black_friday['Product_Category_2'].isna() | black_friday['Product_Category_3'].isna()).sum()/len(black_friday))

type(float((black_friday['Product_Category_2'].isna() | black_friday['Product_Category_3'].isna()).sum()/len(black_friday)))
# Out:
# 0.6944102891306734
# 0.6944102891306734
# 0.6944102891306734
# float

# %%
#q6

black_friday.isnull().sum().max()
# Out:
# 373299

# %%
#q7

black_friday['Product_Category_3'].value_counts().index[0]
# Out:
# 16.0

# %%
#q8

x = (black_friday['Purchase'] - black_friday['Purchase'].min()) / (black_friday['Purchase'].max() - black_friday['Purchase'].min())
x.mean()
# Out:
# 0.3847939036269795

# %%
#q9

x = (black_friday['Purchase'] - black_friday['Purchase'].mean()) / (black_friday['Purchase'].std())
x[(x>-1) & (x<=1)].count()
# Out:
# 348631

# %%
#q10

idx1 = black_friday.index[black_friday['Product_Category_2'].isnull()]
bool((black_friday.loc[idx1, 'Product_Category_2'].isnull() & black_friday.loc[idx1, 'Product_Category_3'].isnull()).all())
# Out:
# True

# %% [markdown]
# ## Questão 1
#
# Quantas observações e quantas colunas há no dataset? Responda no formato de uma tuple `(n_observacoes, n_colunas)`.

# %%
def q1():
    # Retorne aqui o resultado da questão 1.
    return (black_friday.shape[0], black_friday.shape[1])

# %% [markdown]
# ## Questão 2
#
# Há quantas mulheres com idade entre 26 e 35 anos no dataset? Responda como um único escalar.

# %%
def q2():
    # Retorne aqui o resultado da questão 2.
    select = black_friday[(black_friday['Age'] == '26-35') & (black_friday['Gender'] == 'F')]
    return int(select.shape[0])

# %% [markdown]
# ## Questão 3
#
# Quantos usuários únicos há no dataset? Responda como um único escalar.

# %%
def q3():
    # Retorne aqui o resultado da questão 3.
    return int(black_friday['User_ID'].nunique())

# %% [markdown]
# ## Questão 4
#
# Quantos tipos de dados diferentes existem no dataset? Responda como um único escalar.

# %%
def q4():
    # Retorne aqui o resultado da questão 4.
    return int(black_friday.dtypes.nunique())

# %% [markdown]
# ## Questão 5
#
# Qual porcentagem dos registros possui ao menos um valor null (`None`, `ǸaN` etc)? Responda como um único escalar entre 0 e 1.

# %%
def q5():
    # Retorne aqui o resultado da questão 5.
    
    return float((black_friday['Product_Category_2'].isna() | black_friday['Product_Category_3'].isna()).sum()/len(black_friday))

# %% [markdown]
# ## Questão 6
#
# Quantos valores null existem na variável (coluna) com o maior número de null? Responda como um único escalar.

# %%
def q6():
    # Retorne aqui o resultado da questão 6.
    return int(black_friday.isnull().sum().max())

# %% [markdown]
# ## Questão 7
#
# Qual o valor mais frequente (sem contar nulls) em `Product_Category_3`? Responda como um único escalar.

# %%
def q7():
    # Retorne aqui o resultado da questão 7.
    return int(black_friday['Product_Category_3'].value_counts().index[0])

# %% [markdown]
# ## Questão 8
#
# Qual a nova média da variável (coluna) `Purchase` após sua normalização? Responda como um único escalar.

# %%
def q8():
    # Retorne aqui o resultado da questão 8.
    x = (black_friday['Purchase'] - black_friday['Purchase'].min()) / (black_friday['Purchase'].max() - black_friday['Purchase'].min())
    return float(x.mean())

# %% [markdown]
# ## Questão 9
#
# Quantas ocorrências entre -1 e 1 inclusive existem da variáel `Purchase` após sua padronização? Responda como um único escalar.

# %%
def q9():
    # Retorne aqui o resultado da questão 9.
    x = (black_friday['Purchase'] - black_friday['Purchase'].mean()) / (black_friday['Purchase'].std())
    return int(x[(x>-1) & (x<=1)].count())

# %% [markdown]
# ## Questão 10
#
# Podemos afirmar que se uma observação é null em `Product_Category_2` ela também o é em `Product_Category_3`? Responda com um bool (`True`, `False`).

# %%
def q10():
    # Retorne aqui o resultado da questão 10.
    idx1 = black_friday.index[black_friday['Product_Category_2'].isnull()]
    return bool((black_friday.loc[idx1, 'Product_Category_2'].isnull() & black_friday.loc[idx1, 'Product_Category_3'].isnull()).all())
